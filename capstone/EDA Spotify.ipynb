# %%
import pandas as pd
import numpy as np
import openpyxl

import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df1 = pd.read_csv('spotify_2021-04-05.csv')
df2 = pd.read_csv('spotify_2021-04-12.csv')
df3 = pd.read_csv('spotify_2021-04-19.csv')

df = pd.concat([df1,df2,df3])
df.drop(columns=[df.columns[0]], inplace = True)
df.shape
# Out:
# (65909, 1912)

# %%
miss = pd.DataFrame(df.isnull().sum().sort_values(ascending=False), columns=['missing'])
miss['%'] = miss['missing']/df.shape[0]
miss.head(50)
# Out:
#                                missing         %
# classical tenor                  43942  0.666707
# deep indian pop                  43942  0.666707
# italian indie pop                43942  0.666707
# italian tenor                    43942  0.666707
# outsider house                   43942  0.666707
# terrorcore                       43940  0.666677
# drumfunk                         43940  0.666677
# surf music                       43940  0.666677
# bhojpuri pop                     43940  0.666677
# california hardcore              43940  0.666677
# classic greek rock               43940  0.666677
# darkstep                         43940  0.666677
# deep space rock                  43940  0.666677
# acoustic guitar cover            43940  0.666677
# dusseldorf electronic            43940  0.666677
# souldies                         43940  0.666677
# indonesian r&b                   43940  0.666677
# dutch experimental               43940  0.666677
# skansk musik                     43940  0.666677
# indie fuzzpop                    43940  0.666677
# russian oi                       43940  0.666677
# norrbotten indie                 43940  0.666677
# indie electronica                43940  0.666677
# greek pop                        43940  0.666677
# experimental house               43940  0.666677
# dutch experimental electronic    43940  0.666677
# deep norteno                     43936  0.666616
# unblack metal                    43936  0.666616
# alt-idol                         43936  0.666616
# icelandic pop                    43936  0.666616
# icelandic experimental           43936  0.666616
# veracruz indie                   43936  0.666616
# vallenato                        43936  0.666616
# colombian rock                   43936  0.666616
# adoracion                        43936  0.666616
# indie hip hop                    43936  0.666616
# indonesian hip hop               43936  0.666616
# danish jazz                      43936  0.666616
# nwocr                            43936  0.666616
# jazz flute                       43936  0.666616
# background jazz                  43936  0.666616
# christian hardcore               43936  0.666616
# nordic post-rock                 43936  0.666616
# australian children's music      43936  0.666616
# dubsteppe                        43936  0.666616
# russian folk                     43936  0.666616
# sacramento hip hop               43936  0.666616
# czech classical                  43936  0.666616
# banda caliente                   43936  0.666616
# german jazz                      43936  0.666616

# %%
df.fillna(0, inplace = True)

# %%
check_dup_columns = list(df.columns)
check_dup_columns.remove('song_id')
check_dup_columns.remove('date of data pull')

for col in check_dup_columns:
    baseline = df.groupby(['song_id'], as_index = False).agg({'date of data pull':'min'})
    check = df.groupby(['song_id', col], as_index = False).agg({'date of data pull':'min'})
    logging.debug(f'when adding {col} there are {check.shape[0]-baseline.shape[0]} extra rows')
# Out:
# DEBUG:root:when adding song name there are 27 extra rows
# DEBUG:root:when adding album there are 38 extra rows
# DEBUG:root:when adding artist there are 1 extra rows
# DEBUG:root:when adding artist genres there are 2283 extra rows
# DEBUG:root:when adding artist popularity there are 7723 extra rows
# DEBUG:root:when adding artist number of followers there are 36234 extra rows
# DEBUG:root:when adding artist type there are 0 extra rows
# DEBUG:root:when adding album label there are 1 extra rows
# DEBUG:root:when adding album popularity there are 15458 extra rows
# DEBUG:root:when adding song release date there are 25 extra rows
# DEBUG:root:when adding length there are 2 extra rows
# DEBUG:root:when adding song popularity there are 19756 extra rows
# DEBUG:root:when adding key there are 3 extra rows
# DEBUG:root:when adding mode there are 1 extra rows
# DEBUG:root:when adding acousticness there are 36 extra rows
# DEBUG:root:when adding valence there are 65 extra rows
# DEBUG:root:when adding danceability there are 46 extra rows
# DEBUG:root:when adding energy there are 28 extra rows
# DEBUG:root:when adding instrumentalness there are 40 extra rows
# DEBUG:root:when adding liveness there are 4 extra rows
# DEBUG:root:when adding loudness there are 23 extra rows
# DEBUG:root:when adding speechiness there are 56 extra rows
# DEBUG:root:when adding tempo there are 81 extra rows
# DEBUG:root:when adding time signature there are 1 extra rows
# DEBUG:root:when adding tempo confidence there are 41 extra rows
# DEBUG:root:when adding key confidence there are 63 extra rows
# DEBUG:root:when adding time signature confidence there are 29 extra rows
# DEBUG:root:when adding mode confidence there are 62 extra rows
# DEBUG:root:when adding rhythm version there are 0 extra rows
# DEBUG:root:when adding synch version there are 0 extra rows
# DEBUG:root:when adding number of segments there are 20 extra rows
# DEBUG:root:when adding number of bars there are 24 extra rows
# DEBUG:root:when adding number of beats there are 28 extra rows
# DEBUG:root:when adding number of sections there are 17 extra rows
# DEBUG:root:when adding number of tatums there are 28 extra rows
# DEBUG:root:when adding abstract beats there are 0 extra rows
# DEBUG:root:when adding abstract hip hop there are 0 extra rows
# DEBUG:root:when adding acid house there are 0 extra rows
# DEBUG:root:when adding acid jazz there are 0 extra rows
# DEBUG:root:when adding acid rock there are 0 extra rows
# DEBUG:root:when adding acid trance there are 0 extra rows
# DEBUG:root:when adding acoustic pop there are 10 extra rows
# DEBUG:root:when adding acoustic punk there are 0 extra rows
# DEBUG:root:when adding acoustic rock there are 0 extra rows
# DEBUG:root:when adding adoracion there are 0 extra rows
# DEBUG:root:when adding adult standards there are 0 extra rows
# DEBUG:root:when adding afghan pop there are 0 extra rows
# DEBUG:root:when adding african gospel there are 0 extra rows
# DEBUG:root:when adding african percussion there are 0 extra rows
# DEBUG:root:when adding african-american classical there are 0 extra rows
# DEBUG:root:when adding afro dancehall there are 0 extra rows
# DEBUG:root:when adding afro house there are 0 extra rows
# DEBUG:root:when adding afrobeat there are 1 extra rows
# DEBUG:root:when adding afrofuturism there are 0 extra rows
# DEBUG:root:when adding afropop there are 0 extra rows
# DEBUG:root:when adding aggrotech there are 0 extra rows
# DEBUG:root:when adding alabama indie there are 0 extra rows
# DEBUG:root:when adding alabama metal there are 0 extra rows
# DEBUG:root:when adding alabama rap there are 0 extra rows
# DEBUG:root:when adding alaska indie there are 0 extra rows
# DEBUG:root:when adding alberta country there are 0 extra rows
# DEBUG:root:when adding album rock there are 0 extra rows
# DEBUG:root:when adding albuquerque indie there are 0 extra rows
# DEBUG:root:when adding alt z there are 15 extra rows
# DEBUG:root:when adding alt-idol there are 4 extra rows
# DEBUG:root:when adding alternative americana there are 0 extra rows
# DEBUG:root:when adding alternative country there are 6 extra rows
# DEBUG:root:when adding alternative dance there are 1 extra rows
# DEBUG:root:when adding alternative emo there are 0 extra rows
# DEBUG:root:when adding alternative hardcore there are 0 extra rows
# DEBUG:root:when adding alternative hip hop there are 10 extra rows
# DEBUG:root:when adding alternative metal there are 1 extra rows
# DEBUG:root:when adding alternative pop there are 1 extra rows
# DEBUG:root:when adding alternative pop rock there are 0 extra rows
# DEBUG:root:when adding alternative r&b there are 8 extra rows
# DEBUG:root:when adding alternative rock there are 33 extra rows
# DEBUG:root:when adding alternative roots rock there are 0 extra rows
# DEBUG:root:when adding ambeat there are 0 extra rows
# DEBUG:root:when adding ambient there are 0 extra rows
# DEBUG:root:when adding ambient folk there are 0 extra rows
# DEBUG:root:when adding ambient idm there are 0 extra rows
# DEBUG:root:when adding ambient pop there are 0 extra rows
# DEBUG:root:when adding ambient psychill there are 0 extra rows
# DEBUG:root:when adding ambient techno there are 0 extra rows
# DEBUG:root:when adding ambient worship there are 0 extra rows
# DEBUG:root:when adding american contemporary classical there are 0 extra rows
# DEBUG:root:when adding american metalcore there are 0 extra rows
# DEBUG:root:when adding american modern classical there are 0 extra rows
# DEBUG:root:when adding american oi there are 0 extra rows
# DEBUG:root:when adding american post-rock there are 0 extra rows
# DEBUG:root:when adding american romanticism there are 0 extra rows
# DEBUG:root:when adding american shoegaze there are 0 extra rows
# DEBUG:root:when adding anglican liturgy there are 0 extra rows
# DEBUG:root:when adding anime there are 0 extra rows
# DEBUG:root:when adding anime latino there are 0 extra rows
# DEBUG:root:when adding anime rock there are 0 extra rows
# DEBUG:root:when adding anime score there are 0 extra rows
# DEBUG:root:when adding ann arbor indie there are 0 extra rows
# DEBUG:root:when adding anthem emo there are 0 extra rows
# DEBUG:root:when adding anthem worship there are 3 extra rows
# DEBUG:root:when adding anti-folk there are 2 extra rows
# DEBUG:root:when adding antiviral pop there are 0 extra rows
# DEBUG:root:when adding appalachian folk there are 0 extra rows
# DEBUG:root:when adding arab electronic there are 0 extra rows
# DEBUG:root:when adding arab pop there are 0 extra rows
# DEBUG:root:when adding argentine reggae there are 0 extra rows
# DEBUG:root:when adding argentine rock there are 1 extra rows
# DEBUG:root:when adding arizona punk there are 0 extra rows
# DEBUG:root:when adding arkansas country there are 0 extra rows
# DEBUG:root:when adding art pop there are 2 extra rows
# DEBUG:root:when adding art punk there are 0 extra rows
# DEBUG:root:when adding art rock there are 2 extra rows
# DEBUG:root:when adding asbury park indie there are 0 extra rows
# DEBUG:root:when adding asian american hip hop there are 0 extra rows
# DEBUG:root:when adding asmr there are 0 extra rows
# DEBUG:root:when adding assyrian pop there are 0 extra rows
# DEBUG:root:when adding athens indie there are 0 extra rows
# DEBUG:root:when adding atl hip hop there are 0 extra rows
# DEBUG:root:when adding atl trap there are 1 extra rows
# DEBUG:root:when adding atlanta indie there are 0 extra rows
# DEBUG:root:when adding atlanta metal there are 0 extra rows
# DEBUG:root:when adding atlanta punk there are 0 extra rows
# DEBUG:root:when adding atmosphere there are 0 extra rows
# DEBUG:root:when adding atmospheric dnb there are 0 extra rows
# DEBUG:root:when adding atmospheric post-metal there are 0 extra rows
# DEBUG:root:when adding auckland indie there are 0 extra rows
# DEBUG:root:when adding aussie emo there are 0 extra rows
# DEBUG:root:when adding aussietronica there are 0 extra rows
# DEBUG:root:when adding austin americana there are 0 extra rows
# DEBUG:root:when adding austindie there are 0 extra rows
# DEBUG:root:when adding australian alternative pop there are 0 extra rows
# DEBUG:root:when adding australian alternative rock there are 0 extra rows
# DEBUG:root:when adding australian black metal there are 0 extra rows
# DEBUG:root:when adding australian children's music there are 0 extra rows
# DEBUG:root:when adding australian country there are 0 extra rows
# DEBUG:root:when adding australian dance there are 0 extra rows
# DEBUG:root:when adding australian electropop there are 0 extra rows
# DEBUG:root:when adding australian garage punk there are 1 extra rows
# DEBUG:root:when adding australian hip hop there are 0 extra rows
# DEBUG:root:when adding australian house there are 0 extra rows
# DEBUG:root:when adding australian indie there are 0 extra rows
# DEBUG:root:when adding australian indie folk there are 0 extra rows
# DEBUG:root:when adding australian metalcore there are 0 extra rows
# DEBUG:root:when adding australian pop there are 4 extra rows
# DEBUG:root:when adding australian psych there are 0 extra rows
# DEBUG:root:when adding australian reggae fusion there are 0 extra rows
# DEBUG:root:when adding australian rock there are 0 extra rows
# DEBUG:root:when adding austrian punk there are 0 extra rows
# DEBUG:root:when adding austrian techno there are 0 extra rows
# DEBUG:root:when adding avant-garde there are 0 extra rows
# DEBUG:root:when adding avant-garde jazz there are 0 extra rows
# DEBUG:root:when adding azonto there are 0 extra rows
# DEBUG:root:when adding azontobeats there are 0 extra rows
# DEBUG:root:when adding bachata there are 0 extra rows
# DEBUG:root:when adding bachata dominicana there are 0 extra rows
# DEBUG:root:when adding background jazz there are 0 extra rows
# DEBUG:root:when adding background music there are 0 extra rows
# DEBUG:root:when adding bahamian pop there are 0 extra rows
# DEBUG:root:when adding bakersfield sound there are 0 extra rows
# DEBUG:root:when adding balearic there are 0 extra rows
# DEBUG:root:when adding baltic classical there are 0 extra rows
# DEBUG:root:when adding baltimore hip hop there are 0 extra rows
# DEBUG:root:when adding baltimore indie there are 0 extra rows
# DEBUG:root:when adding banda there are 0 extra rows
# DEBUG:root:when adding banda caliente there are 1 extra rows
# DEBUG:root:when adding banda carnavalera there are 0 extra rows
# DEBUG:root:when adding banjo there are 0 extra rows
# DEBUG:root:when adding barbadian pop there are 0 extra rows
# DEBUG:root:when adding barbershop there are 0 extra rows
# DEBUG:root:when adding bardcore there are 0 extra rows
# DEBUG:root:when adding baroque there are 0 extra rows
# DEBUG:root:when adding baroque pop there are 0 extra rows
# DEBUG:root:when adding bass house there are 0 extra rows
# DEBUG:root:when adding bass music there are 0 extra rows
# DEBUG:root:when adding bass trap there are 0 extra rows
# DEBUG:root:when adding bassline there are 0 extra rows
# DEBUG:root:when adding bath indie there are 0 extra rows
# DEBUG:root:when adding baton rouge rap there are 0 extra rows
# DEBUG:root:when adding battle rap there are 0 extra rows
# DEBUG:root:when adding bay area indie there are 0 extra rows
# DEBUG:root:when adding bboy there are 0 extra rows
# DEBUG:root:when adding beatlesque there are 0 extra rows
# DEBUG:root:when adding beats there are 0 extra rows
# DEBUG:root:when adding bebop there are 0 extra rows
# DEBUG:root:when adding bedroom pop there are 0 extra rows
# DEBUG:root:when adding bedroom soul there are 0 extra rows
# DEBUG:root:when adding belarusian electronic there are 0 extra rows
# DEBUG:root:when adding belarusian indie there are 0 extra rows
# DEBUG:root:when adding belarusian pop there are 0 extra rows
# DEBUG:root:when adding belgian dance there are 0 extra rows
# DEBUG:root:when adding belgian edm there are 0 extra rows
# DEBUG:root:when adding belgian indie there are 0 extra rows
# DEBUG:root:when adding belgian indie rock there are 0 extra rows
# DEBUG:root:when adding belgian new wave there are 0 extra rows
# DEBUG:root:when adding belgian pop there are 0 extra rows
# DEBUG:root:when adding belgian rock there are 0 extra rows
# DEBUG:root:when adding belly dance there are 0 extra rows
# DEBUG:root:when adding bergen indie there are 0 extra rows
# DEBUG:root:when adding berlin school there are 0 extra rows
# DEBUG:root:when adding bhangra there are 0 extra rows
# DEBUG:root:when adding big band there are 0 extra rows
# DEBUG:root:when adding big beat there are 0 extra rows
# DEBUG:root:when adding big room there are 0 extra rows
# DEBUG:root:when adding birmingham metal there are 0 extra rows
# DEBUG:root:when adding bitpop there are 0 extra rows
# DEBUG:root:when adding black 'n' roll there are 0 extra rows
# DEBUG:root:when adding black comedy there are 0 extra rows
# DEBUG:root:when adding black metal there are 0 extra rows
# DEBUG:root:when adding black punk there are 0 extra rows
# DEBUG:root:when adding black sludge there are 0 extra rows
# DEBUG:root:when adding black thrash there are 0 extra rows
# DEBUG:root:when adding blackgaze there are 0 extra rows
# DEBUG:root:when adding bleep techno there are 0 extra rows
# DEBUG:root:when adding bluegrass there are 0 extra rows
# DEBUG:root:when adding bluegrass gospel there are 0 extra rows
# DEBUG:root:when adding blues there are 0 extra rows
# DEBUG:root:when adding blues rock there are 22 extra rows
# DEBUG:root:when adding bmore there are 0 extra rows
# DEBUG:root:when adding bolero there are 0 extra rows
# DEBUG:root:when adding boogaloo there are 0 extra rows
# DEBUG:root:when adding boogie there are 0 extra rows
# DEBUG:root:when adding boom bap there are 0 extra rows
# DEBUG:root:when adding bosnian electronic there are 0 extra rows
# DEBUG:root:when adding bossa nova there are 0 extra rows
# DEBUG:root:when adding bossa nova cover there are 0 extra rows
# DEBUG:root:when adding boston hardcore there are 0 extra rows
# DEBUG:root:when adding boston hip hop there are 0 extra rows
# DEBUG:root:when adding boston indie there are 0 extra rows
# DEBUG:root:when adding boston metal there are 0 extra rows
# DEBUG:root:when adding boston punk there are 0 extra rows
# DEBUG:root:when adding boston rock there are 0 extra rows
# DEBUG:root:when adding bounce there are 0 extra rows
# DEBUG:root:when adding bouncy house there are 0 extra rows
# DEBUG:root:when adding bouzouki there are 0 extra rows
# DEBUG:root:when adding bow pop there are 0 extra rows
# DEBUG:root:when adding boy band there are 0 extra rows
# DEBUG:root:when adding braindance there are 0 extra rows
# DEBUG:root:when adding brass band there are 0 extra rows
# DEBUG:root:when adding brazilian black metal there are 0 extra rows
# DEBUG:root:when adding brazilian blues there are 0 extra rows
# DEBUG:root:when adding brazilian boogie there are 0 extra rows
# DEBUG:root:when adding brazilian dnb there are 0 extra rows
# DEBUG:root:when adding brazilian edm there are 0 extra rows
# DEBUG:root:when adding brazilian grindcore there are 0 extra rows
# DEBUG:root:when adding brazilian metal there are 0 extra rows
# DEBUG:root:when adding brazilian power metal there are 0 extra rows
# DEBUG:root:when adding breakbeat there are 0 extra rows
# DEBUG:root:when adding breakcore there are 0 extra rows
# DEBUG:root:when adding brighton indie there are 0 extra rows
# DEBUG:root:when adding brill building pop there are 0 extra rows
# DEBUG:root:when adding bristol electronic there are 0 extra rows
# DEBUG:root:when adding british alternative rock there are 0 extra rows
# DEBUG:root:when adding british blues there are 0 extra rows
# DEBUG:root:when adding british brass band there are 0 extra rows
# DEBUG:root:when adding british comedy there are 0 extra rows
# DEBUG:root:when adding british contemporary classical there are 0 extra rows
# DEBUG:root:when adding british folk there are 0 extra rows
# DEBUG:root:when adding british indie rock there are 0 extra rows
# DEBUG:root:when adding british industrial there are 0 extra rows
# DEBUG:root:when adding british invasion there are 0 extra rows
# DEBUG:root:when adding british post-rock there are 0 extra rows
# DEBUG:root:when adding british power metal there are 0 extra rows
# DEBUG:root:when adding british singer-songwriter there are 0 extra rows
# DEBUG:root:when adding british soul there are 0 extra rows
# DEBUG:root:when adding british soundtrack there are 0 extra rows
# DEBUG:root:when adding britpop there are 0 extra rows
# DEBUG:root:when adding broadway there are 1 extra rows
# DEBUG:root:when adding broken beat there are 0 extra rows
# DEBUG:root:when adding bronx hip hop there are 0 extra rows
# DEBUG:root:when adding brooklyn drill there are 0 extra rows
# DEBUG:root:when adding brooklyn indie there are 0 extra rows
# DEBUG:root:when adding brostep there are 0 extra rows
# DEBUG:root:when adding brutal death metal there are 0 extra rows
# DEBUG:root:when adding brutal deathcore there are 0 extra rows
# DEBUG:root:when adding bubble trance there are 0 extra rows
# DEBUG:root:when adding bubblegrunge there are 1 extra rows
# DEBUG:root:when adding bubblegum dance there are 1 extra rows
# DEBUG:root:when adding bubblegum pop there are 21 extra rows
# DEBUG:root:when adding buffalo ny metal there are 0 extra rows
# DEBUG:root:when adding bulgarian electronic there are 0 extra rows
# DEBUG:root:when adding c-pop there are 0 extra rows
# DEBUG:root:when adding c86 there are 0 extra rows
# DEBUG:root:when adding cali rap there are 0 extra rows
# DEBUG:root:when adding calming instrumental there are 1 extra rows
# DEBUG:root:when adding calypso there are 0 extra rows
# DEBUG:root:when adding cambodian pop there are 0 extra rows
# DEBUG:root:when adding canadian americana there are 0 extra rows
# DEBUG:root:when adding canadian ccm there are 0 extra rows
# DEBUG:root:when adding canadian celtic there are 0 extra rows
# DEBUG:root:when adding canadian children's music there are 0 extra rows
# DEBUG:root:when adding canadian classical there are 0 extra rows
# DEBUG:root:when adding canadian comedy there are 0 extra rows
# DEBUG:root:when adding canadian contemporary country there are 0 extra rows
# DEBUG:root:when adding canadian contemporary r&b there are 0 extra rows
# DEBUG:root:when adding canadian country there are 0 extra rows
# DEBUG:root:when adding canadian electronic there are 0 extra rows
# DEBUG:root:when adding canadian electropop there are 0 extra rows
# DEBUG:root:when adding canadian experimental there are 0 extra rows
# DEBUG:root:when adding canadian folk there are 0 extra rows
# DEBUG:root:when adding canadian hardcore there are 0 extra rows
# DEBUG:root:when adding canadian hip hop there are 0 extra rows
# DEBUG:root:when adding canadian house there are 0 extra rows
# DEBUG:root:when adding canadian indie there are 0 extra rows
# DEBUG:root:when adding canadian indie folk there are 0 extra rows
# DEBUG:root:when adding canadian latin there are 0 extra rows
# DEBUG:root:when adding canadian metal there are 0 extra rows
# DEBUG:root:when adding canadian old school hip hop there are 0 extra rows
# DEBUG:root:when adding canadian pop there are 0 extra rows
# DEBUG:root:when adding canadian pop punk there are 0 extra rows
# DEBUG:root:when adding canadian post-hardcore there are 0 extra rows
# DEBUG:root:when adding canadian punk there are 0 extra rows
# DEBUG:root:when adding canadian rock there are 0 extra rows
# DEBUG:root:when adding canadian singer-songwriter there are 1 extra rows
# DEBUG:root:when adding canadian soundtrack there are 0 extra rows
# DEBUG:root:when adding cancion melodica there are 0 extra rows
# DEBUG:root:when adding candy pop there are 0 extra rows
# DEBUG:root:when adding cantautor there are 0 extra rows
# DEBUG:root:when adding canto popular uruguayo there are 0 extra rows
# DEBUG:root:when adding cantopop there are 0 extra rows
# DEBUG:root:when adding canzone d'autore there are 0 extra rows
# DEBUG:root:when adding canzone napoletana there are 0 extra rows
# DEBUG:root:when adding carnaval there are 0 extra rows
# DEBUG:root:when adding cartoon there are 0 extra rows
# DEBUG:root:when adding ccm there are 0 extra rows
# DEBUG:root:when adding cello there are 0 extra rows
# DEBUG:root:when adding celtic there are 0 extra rows
# DEBUG:root:when adding celtic metal there are 0 extra rows
# DEBUG:root:when adding celtic punk there are 0 extra rows
# DEBUG:root:when adding celtic rock there are 0 extra rows
# DEBUG:root:when adding cha-cha-cha there are 0 extra rows
# DEBUG:root:when adding chamber choir there are 0 extra rows
# DEBUG:root:when adding chamber pop there are 2 extra rows
# DEBUG:root:when adding chamber psych there are 2 extra rows
# DEBUG:root:when adding channel islands indie there are 0 extra rows
# DEBUG:root:when adding chanson there are 0 extra rows
# DEBUG:root:when adding charlottesville indie there are 0 extra rows
# DEBUG:root:when adding chicago blues there are 0 extra rows
# DEBUG:root:when adding chicago drill there are 0 extra rows
# DEBUG:root:when adding chicago hardcore there are 0 extra rows
# DEBUG:root:when adding chicago house there are 0 extra rows
# DEBUG:root:when adding chicago indie there are 0 extra rows
# DEBUG:root:when adding chicago punk there are 0 extra rows
# DEBUG:root:when adding chicago rap there are 0 extra rows
# DEBUG:root:when adding chicago soul there are 0 extra rows
# DEBUG:root:when adding chicano rap there are 0 extra rows
# DEBUG:root:when adding chicha there are 0 extra rows
# DEBUG:root:when adding children's folk there are 0 extra rows
# DEBUG:root:when adding children's music there are 0 extra rows
# DEBUG:root:when adding chilean hardcore there are 0 extra rows
# DEBUG:root:when adding chilean rock there are 0 extra rows
# DEBUG:root:when adding chilena there are 0 extra rows
# DEBUG:root:when adding chill groove there are 0 extra rows
# DEBUG:root:when adding chill lounge there are 0 extra rows
# DEBUG:root:when adding chill r&b there are 3 extra rows
# DEBUG:root:when adding chillhop there are 0 extra rows
# DEBUG:root:when adding chillstep there are 0 extra rows
# DEBUG:root:when adding chillwave there are 5 extra rows
# DEBUG:root:when adding chinese classical there are 0 extra rows
# DEBUG:root:when adding chinese indie there are 0 extra rows
# DEBUG:root:when adding chinese indie pop there are 0 extra rows
# DEBUG:root:when adding chinese traditional there are 0 extra rows
# DEBUG:root:when adding chip hop there are 0 extra rows
# DEBUG:root:when adding chiptune there are 0 extra rows
# DEBUG:root:when adding chopped and screwed there are 0 extra rows
# DEBUG:root:when adding choral there are 0 extra rows
# DEBUG:root:when adding christian a cappella there are 0 extra rows
# DEBUG:root:when adding christian alternative rock there are 0 extra rows
# DEBUG:root:when adding christian hard rock there are 0 extra rows
# DEBUG:root:when adding christian hardcore there are 0 extra rows
# DEBUG:root:when adding christian hip hop there are 1 extra rows
# DEBUG:root:when adding christian indie there are 0 extra rows
# DEBUG:root:when adding christian metal there are 0 extra rows
# DEBUG:root:when adding christian metalcore there are 0 extra rows
# DEBUG:root:when adding christian music there are 5 extra rows
# DEBUG:root:when adding christian pop there are 4 extra rows
# DEBUG:root:when adding christian power metal there are 0 extra rows
# DEBUG:root:when adding christian punk there are 0 extra rows
# DEBUG:root:when adding christian relaxative there are 0 extra rows
# DEBUG:root:when adding christian rock there are 1 extra rows
# DEBUG:root:when adding christian thrash metal there are 0 extra rows
# DEBUG:root:when adding christian trap there are 1 extra rows
# DEBUG:root:when adding christian uplift there are 1 extra rows
# DEBUG:root:when adding christmas instrumental there are 0 extra rows
# DEBUG:root:when adding chunchaca there are 0 extra rows
# DEBUG:root:when adding chutney there are 0 extra rows
# DEBUG:root:when adding cinematic post-rock there are 0 extra rows
# DEBUG:root:when adding circuit there are 0 extra rows
# DEBUG:root:when adding city pop there are 0 extra rows
# DEBUG:root:when adding classic afrobeat there are 0 extra rows
# DEBUG:root:when adding classic australian country there are 0 extra rows
# DEBUG:root:when adding classic belgian pop there are 0 extra rows
# DEBUG:root:when adding classic bhangra there are 0 extra rows
# DEBUG:root:when adding classic canadian rock there are 0 extra rows
# DEBUG:root:when adding classic cantopop there are 0 extra rows
# DEBUG:root:when adding classic city pop there are 0 extra rows
# DEBUG:root:when adding classic country pop there are 0 extra rows
# DEBUG:root:when adding classic dubstep there are 0 extra rows
# DEBUG:root:when adding classic garage rock there are 20 extra rows
# DEBUG:root:when adding classic girl group there are 0 extra rows
# DEBUG:root:when adding classic greek pop there are 0 extra rows
# DEBUG:root:when adding classic hardstyle there are 0 extra rows
# DEBUG:root:when adding classic house there are 3 extra rows
# DEBUG:root:when adding classic icelandic pop there are 0 extra rows
# DEBUG:root:when adding classic indo pop there are 0 extra rows
# DEBUG:root:when adding classic indonesian rock there are 0 extra rows
# DEBUG:root:when adding classic italian pop there are 0 extra rows
# DEBUG:root:when adding classic j-pop there are 0 extra rows
# DEBUG:root:when adding classic j-rock there are 0 extra rows
# DEBUG:root:when adding classic k-pop there are 0 extra rows
# DEBUG:root:when adding classic malaysian pop there are 0 extra rows
# DEBUG:root:when adding classic mandopop there are 0 extra rows
# DEBUG:root:when adding classic nz pop there are 0 extra rows
# DEBUG:root:when adding classic progressive house there are 0 extra rows
# DEBUG:root:when adding classic rock there are 108 extra rows
# DEBUG:root:when adding classic schlager there are 0 extra rows
# DEBUG:root:when adding classic soul there are 1 extra rows
# DEBUG:root:when adding classic soundtrack there are 0 extra rows
# DEBUG:root:when adding classic swedish pop there are 0 extra rows
# DEBUG:root:when adding classic thai pop there are 0 extra rows
# DEBUG:root:when adding classic uk pop there are 0 extra rows
# DEBUG:root:when adding classical there are 0 extra rows
# DEBUG:root:when adding classical era there are 0 extra rows
# DEBUG:root:when adding classical performance there are 0 extra rows
# DEBUG:root:when adding classical piano there are 0 extra rows
# DEBUG:root:when adding classify there are 0 extra rows
# DEBUG:root:when adding cleveland metal there are 0 extra rows
# DEBUG:root:when adding collage pop there are 0 extra rows
# DEBUG:root:when adding cologne electronic there are 0 extra rows
# DEBUG:root:when adding colombian pop there are 0 extra rows
# DEBUG:root:when adding colombian rock there are 0 extra rows
# DEBUG:root:when adding comedy there are 1 extra rows
# DEBUG:root:when adding comedy rap there are 0 extra rows
# DEBUG:root:when adding comedy rock there are 0 extra rows
# DEBUG:root:when adding comic there are 0 extra rows
# DEBUG:root:when adding comic metal there are 0 extra rows
# DEBUG:root:when adding complextro there are 0 extra rows
# DEBUG:root:when adding compositional ambient there are 0 extra rows
# DEBUG:root:when adding concert band there are 0 extra rows
# DEBUG:root:when adding connecticut hardcore there are 0 extra rows
# DEBUG:root:when adding conscious hip hop there are 0 extra rows
# DEBUG:root:when adding contemporary classical there are 0 extra rows
# DEBUG:root:when adding contemporary country there are 2 extra rows
# DEBUG:root:when adding contemporary gospel there are 0 extra rows
# DEBUG:root:when adding contemporary jazz there are 0 extra rows
# DEBUG:root:when adding contemporary post-bop there are 0 extra rows
# DEBUG:root:when adding contemporary vocal jazz there are 0 extra rows
# DEBUG:root:when adding cool jazz there are 1 extra rows
# DEBUG:root:when adding cornish folk there are 0 extra rows
# DEBUG:root:when adding corrido there are 1 extra rows
# DEBUG:root:when adding corridos tumbados there are 0 extra rows
# DEBUG:root:when adding cosmic american there are 0 extra rows
# DEBUG:root:when adding cosmic black metal there are 0 extra rows
# DEBUG:root:when adding cosmic post-rock there are 0 extra rows
# DEBUG:root:when adding cosmic uplifting trance there are 0 extra rows
# DEBUG:root:when adding country there are 11 extra rows
# DEBUG:root:when adding country blues there are 0 extra rows
# DEBUG:root:when adding country boogie there are 0 extra rows
# DEBUG:root:when adding country dawn there are 0 extra rows
# DEBUG:root:when adding country gospel there are 0 extra rows
# DEBUG:root:when adding country pop there are 1 extra rows
# DEBUG:root:when adding country rap there are 0 extra rows
# DEBUG:root:when adding country road there are 0 extra rows
# DEBUG:root:when adding country rock there are 28 extra rows
# DEBUG:root:when adding coverchill there are 0 extra rows
# DEBUG:root:when adding cowboy western there are 0 extra rows
# DEBUG:root:when adding cowpunk there are 0 extra rows
# DEBUG:root:when adding croatian electronic there are 0 extra rows
# DEBUG:root:when adding croatian pop there are 0 extra rows
# DEBUG:root:when adding crossover prog there are 0 extra rows
# DEBUG:root:when adding crossover thrash there are 0 extra rows
# DEBUG:root:when adding crunk there are 0 extra rows
# DEBUG:root:when adding cuatro venezolano there are 0 extra rows
# DEBUG:root:when adding cuban rumba there are 0 extra rows
# DEBUG:root:when adding cubaton there are 0 extra rows
# DEBUG:root:when adding cumbia there are 3 extra rows
# DEBUG:root:when adding cumbia andina mexicana there are 0 extra rows
# DEBUG:root:when adding cumbia chilena there are 0 extra rows
# DEBUG:root:when adding cumbia colombiana regia there are 0 extra rows
# DEBUG:root:when adding cumbia paraguaya there are 0 extra rows
# DEBUG:root:when adding cumbia salvadorena there are 0 extra rows
# DEBUG:root:when adding cumbia sonidera there are 0 extra rows
# DEBUG:root:when adding cumbia villera there are 0 extra rows
# DEBUG:root:when adding cyberpunk there are 0 extra rows
# DEBUG:root:when adding czech classical there are 0 extra rows
# DEBUG:root:when adding czsk hip hop there are 0 extra rows
# DEBUG:root:when adding dakke dak there are 0 extra rows
# DEBUG:root:when adding dance pop there are 34 extra rows
# DEBUG:root:when adding dance rock there are 268 extra rows
# DEBUG:root:when adding dance-punk there are 5 extra rows
# DEBUG:root:when adding dancehall there are 0 extra rows
# DEBUG:root:when adding danish alternative rock there are 0 extra rows
# DEBUG:root:when adding danish classical there are 0 extra rows
# DEBUG:root:when adding danish electronic there are 0 extra rows
# DEBUG:root:when adding danish jazz there are 0 extra rows
# DEBUG:root:when adding danish metal there are 0 extra rows
# DEBUG:root:when adding danish pop there are 0 extra rows
# DEBUG:root:when adding danish rock there are 0 extra rows
# DEBUG:root:when adding dansktop there are 0 extra rows
# DEBUG:root:when adding dark cabaret there are 0 extra rows
# DEBUG:root:when adding dark clubbing there are 0 extra rows
# DEBUG:root:when adding dark electro there are 0 extra rows
# DEBUG:root:when adding dark minimal techno there are 0 extra rows
# DEBUG:root:when adding dark post-punk there are 0 extra rows
# DEBUG:root:when adding dark progressive house there are 0 extra rows
# DEBUG:root:when adding dark techno there are 0 extra rows
# DEBUG:root:when adding dark trap there are 4 extra rows
# DEBUG:root:when adding dark wave there are 0 extra rows
# DEBUG:root:when adding dayton indie there are 0 extra rows
# DEBUG:root:when adding dc hardcore there are 0 extra rows
# DEBUG:root:when adding death metal there are 0 extra rows
# DEBUG:root:when adding deathcore there are 1 extra rows
# DEBUG:root:when adding deathgrass there are 0 extra rows
# DEBUG:root:when adding deathrash there are 0 extra rows
# DEBUG:root:when adding deep big room there are 0 extra rows
# DEBUG:root:when adding deep ccm there are 0 extra rows
# DEBUG:root:when adding deep chill there are 3 extra rows
# DEBUG:root:when adding deep comedy there are 0 extra rows
# DEBUG:root:when adding deep deep house there are 0 extra rows
# DEBUG:root:when adding deep deep tech house there are 0 extra rows
# DEBUG:root:when adding deep disco house there are 0 extra rows
# DEBUG:root:when adding deep dubstep there are 0 extra rows
# DEBUG:root:when adding deep euro house there are 0 extra rows
# DEBUG:root:when adding deep eurodance there are 0 extra rows
# DEBUG:root:when adding deep free jazz there are 0 extra rows
# DEBUG:root:when adding deep full on there are 0 extra rows
# DEBUG:root:when adding deep german punk there are 0 extra rows
# DEBUG:root:when adding deep groove house there are 1 extra rows
# DEBUG:root:when adding deep happy hardcore there are 0 extra rows
# DEBUG:root:when adding deep house there are 10 extra rows
# DEBUG:root:when adding deep latin christian there are 0 extra rows
# DEBUG:root:when adding deep minimal techno there are 0 extra rows
# DEBUG:root:when adding deep new americana there are 2 extra rows
# DEBUG:root:when adding deep norteno there are 0 extra rows
# DEBUG:root:when adding deep pop edm there are 0 extra rows
# DEBUG:root:when adding deep progressive trance there are 0 extra rows
# DEBUG:root:when adding deep regional mexican there are 0 extra rows
# DEBUG:root:when adding deep soul house there are 0 extra rows
# DEBUG:root:when adding deep southern soul there are 0 extra rows
# DEBUG:root:when adding deep southern trap there are 3 extra rows
# DEBUG:root:when adding deep talent show there are 0 extra rows
# DEBUG:root:when adding deep tech house there are 0 extra rows
# DEBUG:root:when adding deep tropical house there are 1 extra rows
# DEBUG:root:when adding deep underground hip hop there are 0 extra rows
# DEBUG:root:when adding deep uplifting trance there are 17 extra rows
# DEBUG:root:when adding dembow there are 0 extra rows
# DEBUG:root:when adding denton tx indie there are 0 extra rows
# DEBUG:root:when adding depressive black metal there are 0 extra rows
# DEBUG:root:when adding desert blues there are 0 extra rows
# DEBUG:root:when adding desi hip hop there are 1 extra rows
# DEBUG:root:when adding desi pop there are 0 extra rows
# DEBUG:root:when adding destroy techno there are 0 extra rows
# DEBUG:root:when adding detroit hip hop there are 0 extra rows
# DEBUG:root:when adding detroit rock there are 0 extra rows
# DEBUG:root:when adding detroit trap there are 0 extra rows
# DEBUG:root:when adding dfw rap there are 0 extra rows
# DEBUG:root:when adding didgeridoo there are 0 extra rows
# DEBUG:root:when adding digital hardcore there are 0 extra rows
# DEBUG:root:when adding dinner jazz there are 0 extra rows
# DEBUG:root:when adding dirty south rap there are 22 extra rows
# DEBUG:root:when adding dirty texas rap there are 0 extra rows
# DEBUG:root:when adding disco there are 2 extra rows
# DEBUG:root:when adding disco house there are 19 extra rows
# DEBUG:root:when adding disco polo there are 0 extra rows
# DEBUG:root:when adding discofox there are 0 extra rows
# DEBUG:root:when adding disney there are 0 extra rows
# DEBUG:root:when adding diva house there are 0 extra rows
# DEBUG:root:when adding dixieland there are 0 extra rows
# DEBUG:root:when adding djent there are 0 extra rows
# DEBUG:root:when adding dmv rap there are 0 extra rows
# DEBUG:root:when adding dominican pop there are 2 extra rows
# DEBUG:root:when adding dong-yo there are 0 extra rows
# DEBUG:root:when adding doo-wop there are 0 extra rows
# DEBUG:root:when adding doom metal there are 0 extra rows
# DEBUG:root:when adding doomcore there are 0 extra rows
# DEBUG:root:when adding dortmund indie there are 0 extra rows
# DEBUG:root:when adding double drumming there are 0 extra rows
# DEBUG:root:when adding downtempo there are 0 extra rows
# DEBUG:root:when adding downtempo bass there are 0 extra rows
# DEBUG:root:when adding dream pop there are 4 extra rows
# DEBUG:root:when adding dream trance there are 0 extra rows
# DEBUG:root:when adding dreamo there are 0 extra rows
# DEBUG:root:when adding drift there are 0 extra rows
# DEBUG:root:when adding drill there are 0 extra rows
# DEBUG:root:when adding drill and bass there are 0 extra rows
# DEBUG:root:when adding drone there are 0 extra rows
# DEBUG:root:when adding drone metal there are 1 extra rows
# DEBUG:root:when adding drum and bass there are 0 extra rows
# DEBUG:root:when adding dub there are 0 extra rows
# DEBUG:root:when adding dub reggae there are 0 extra rows
# DEBUG:root:when adding dubstep there are 0 extra rows
# DEBUG:root:when adding dubstep product there are 0 extra rows
# DEBUG:root:when adding dubsteppe there are 0 extra rows
# DEBUG:root:when adding duluth indie there are 0 extra rows
# DEBUG:root:when adding dunedin indie there are 0 extra rows
# DEBUG:root:when adding dunedin sound there are 0 extra rows
# DEBUG:root:when adding duranguense there are 0 extra rows
# DEBUG:root:when adding dutch americana there are 0 extra rows
# DEBUG:root:when adding dutch death metal there are 0 extra rows
# DEBUG:root:when adding dutch edm there are 0 extra rows
# DEBUG:root:when adding dutch hip hop there are 0 extra rows
# DEBUG:root:when adding dutch house there are 2 extra rows
# DEBUG:root:when adding dutch metal there are 0 extra rows
# DEBUG:root:when adding dutch pop there are 0 extra rows
# DEBUG:root:when adding dutch prog there are 0 extra rows
# DEBUG:root:when adding dutch punk rock there are 0 extra rows
# DEBUG:root:when adding dutch rock there are 0 extra rows
# DEBUG:root:when adding dutch tech house there are 0 extra rows
# DEBUG:root:when adding dutch trance there are 0 extra rows
# DEBUG:root:when adding early american folk there are 0 extra rows
# DEBUG:root:when adding early avant garde there are 0 extra rows
# DEBUG:root:when adding early modern classical there are 0 extra rows
# DEBUG:root:when adding early music there are 1 extra rows
# DEBUG:root:when adding early romantic era there are 0 extra rows
# DEBUG:root:when adding early us punk there are 0 extra rows
# DEBUG:root:when adding east coast hip hop there are 0 extra rows
# DEBUG:root:when adding east coast reggae there are 0 extra rows
# DEBUG:root:when adding easy listening there are 0 extra rows
# DEBUG:root:when adding easycore there are 0 extra rows
# DEBUG:root:when adding eau claire indie there are 0 extra rows
# DEBUG:root:when adding ebm there are 0 extra rows
# DEBUG:root:when adding ecm-style jazz there are 0 extra rows
# DEBUG:root:when adding ectofolk there are 0 extra rows
# DEBUG:root:when adding ecuadorian pop there are 0 extra rows
# DEBUG:root:when adding edm there are 15 extra rows
# DEBUG:root:when adding edmonton indie there are 0 extra rows
# DEBUG:root:when adding el paso indie there are 0 extra rows
# DEBUG:root:when adding electra there are 0 extra rows
# DEBUG:root:when adding electric bass there are 0 extra rows
# DEBUG:root:when adding electric blues there are 1 extra rows
# DEBUG:root:when adding electro there are 1 extra rows
# DEBUG:root:when adding electro house there are 45 extra rows
# DEBUG:root:when adding electro latino there are 0 extra rows
# DEBUG:root:when adding electro swing there are 0 extra rows
# DEBUG:root:when adding electro-industrial there are 0 extra rows
# DEBUG:root:when adding electroclash there are 0 extra rows
# DEBUG:root:when adding electronic djent there are 0 extra rows
# DEBUG:root:when adding electronic rock there are 0 extra rows
# DEBUG:root:when adding electronic trap there are 0 extra rows
# DEBUG:root:when adding electronica there are 12 extra rows
# DEBUG:root:when adding electropop there are 3 extra rows
# DEBUG:root:when adding electropowerpop there are 0 extra rows
# DEBUG:root:when adding elektropunk there are 0 extra rows
# DEBUG:root:when adding elephant 6 there are 0 extra rows
# DEBUG:root:when adding emo there are 0 extra rows
# DEBUG:root:when adding emo punk there are 0 extra rows
# DEBUG:root:when adding emo rap there are 0 extra rows
# DEBUG:root:when adding english baroque there are 0 extra rows
# DEBUG:root:when adding english indie rock there are 0 extra rows
# DEBUG:root:when adding entehno there are 0 extra rows
# DEBUG:root:when adding environmental there are 0 extra rows
# DEBUG:root:when adding epicore there are 0 extra rows
# DEBUG:root:when adding escape room there are 3 extra rows
# DEBUG:root:when adding ethereal wave there are 0 extra rows
# DEBUG:root:when adding etherpop there are 0 extra rows
# DEBUG:root:when adding ethnotronica there are 0 extra rows
# DEBUG:root:when adding euphoric hardstyle there are 0 extra rows
# DEBUG:root:when adding eurodance there are 0 extra rows
# DEBUG:root:when adding europop there are 7 extra rows
# DEBUG:root:when adding euroska there are 0 extra rows
# DEBUG:root:when adding eurovision there are 0 extra rows
# DEBUG:root:when adding experimental there are 0 extra rows
# DEBUG:root:when adding experimental ambient there are 0 extra rows
# DEBUG:root:when adding experimental folk there are 0 extra rows
# DEBUG:root:when adding experimental hip hop there are 0 extra rows
# DEBUG:root:when adding experimental pop there are 0 extra rows
# DEBUG:root:when adding experimental rock there are 0 extra rows
# DEBUG:root:when adding experimental vocal there are 0 extra rows
# DEBUG:root:when adding fake there are 0 extra rows
# DEBUG:root:when adding faroese pop there are 0 extra rows
# DEBUG:root:when adding fast melodic punk there are 0 extra rows
# DEBUG:root:when adding fidget house there are 0 extra rows
# DEBUG:root:when adding filmi there are 0 extra rows
# DEBUG:root:when adding filter house there are 1 extra rows
# DEBUG:root:when adding filthstep there are 0 extra rows
# DEBUG:root:when adding finnish black metal there are 0 extra rows
# DEBUG:root:when adding finnish death metal there are 0 extra rows
# DEBUG:root:when adding finnish doom metal there are 0 extra rows
# DEBUG:root:when adding finnish edm there are 0 extra rows
# DEBUG:root:when adding finnish electro there are 0 extra rows
# DEBUG:root:when adding finnish melodeath there are 0 extra rows
# DEBUG:root:when adding finnish metal there are 0 extra rows
# DEBUG:root:when adding finnish power metal there are 0 extra rows
# DEBUG:root:when adding firenze indie there are 0 extra rows
# DEBUG:root:when adding flamenco there are 0 extra rows
# DEBUG:root:when adding flint hip hop there are 0 extra rows
# DEBUG:root:when adding float house there are 0 extra rows
# DEBUG:root:when adding florida rap there are 0 extra rows
# DEBUG:root:when adding focus beats there are 2 extra rows
# DEBUG:root:when adding focus trance there are 0 extra rows
# DEBUG:root:when adding folk there are 1 extra rows
# DEBUG:root:when adding folk metal there are 0 extra rows
# DEBUG:root:when adding folk punk there are 0 extra rows
# DEBUG:root:when adding folk rock there are 60 extra rows
# DEBUG:root:when adding folk rock italiano there are 0 extra rows
# DEBUG:root:when adding folk-pop there are 0 extra rows
# DEBUG:root:when adding folktronica there are 0 extra rows
# DEBUG:root:when adding footwork there are 0 extra rows
# DEBUG:root:when adding forest psy there are 0 extra rows
# DEBUG:root:when adding fourth world there are 0 extra rows
# DEBUG:root:when adding freak folk there are 37 extra rows
# DEBUG:root:when adding freakbeat there are 0 extra rows
# DEBUG:root:when adding free jazz there are 0 extra rows
# DEBUG:root:when adding freestyle there are 1 extra rows
# DEBUG:root:when adding french classical piano there are 0 extra rows
# DEBUG:root:when adding french death metal there are 0 extra rows
# DEBUG:root:when adding french indie pop there are 0 extra rows
# DEBUG:root:when adding french metal there are 0 extra rows
# DEBUG:root:when adding french opera there are 0 extra rows
# DEBUG:root:when adding french pop there are 0 extra rows
# DEBUG:root:when adding french post-punk there are 0 extra rows
# DEBUG:root:when adding french punk there are 0 extra rows
# DEBUG:root:when adding french rock there are 0 extra rows
# DEBUG:root:when adding french romanticism there are 0 extra rows
# DEBUG:root:when adding french shoegaze there are 0 extra rows
# DEBUG:root:when adding french soundtrack there are 0 extra rows
# DEBUG:root:when adding french synthpop there are 0 extra rows
# DEBUG:root:when adding french tech house there are 0 extra rows
# DEBUG:root:when adding french techno there are 0 extra rows
# DEBUG:root:when adding frenchcore there are 0 extra rows
# DEBUG:root:when adding full on there are 0 extra rows
# DEBUG:root:when adding funana there are 0 extra rows
# DEBUG:root:when adding funk there are 3 extra rows
# DEBUG:root:when adding funk metal there are 0 extra rows
# DEBUG:root:when adding funk rock there are 0 extra rows
# DEBUG:root:when adding funky breaks there are 2 extra rows
# DEBUG:root:when adding funky house there are 0 extra rows
# DEBUG:root:when adding funky tech house there are 0 extra rows
# DEBUG:root:when adding future bass there are 4 extra rows
# DEBUG:root:when adding future funk there are 0 extra rows
# DEBUG:root:when adding future garage there are 0 extra rows
# DEBUG:root:when adding future house there are 0 extra rows
# DEBUG:root:when adding future rock there are 0 extra rows
# DEBUG:root:when adding futurepop there are 0 extra rows
# DEBUG:root:when adding g funk there are 0 extra rows
# DEBUG:root:when adding g-house there are 0 extra rows
# DEBUG:root:when adding gabba there are 0 extra rows
# DEBUG:root:when adding gainesville indie there are 0 extra rows
# DEBUG:root:when adding gaming edm there are 0 extra rows
# DEBUG:root:when adding gangster rap there are 40 extra rows
# DEBUG:root:when adding garage pop there are 0 extra rows
# DEBUG:root:when adding garage psych there are 0 extra rows
# DEBUG:root:when adding garage punk there are 0 extra rows
# DEBUG:root:when adding garage rock there are 0 extra rows
# DEBUG:root:when adding garage rock revival there are 0 extra rows
# DEBUG:root:when adding gauze pop there are 0 extra rows
# DEBUG:root:when adding geek rock there are 0 extra rows
# DEBUG:root:when adding german alternative rock there are 0 extra rows
# DEBUG:root:when adding german baroque there are 0 extra rows
# DEBUG:root:when adding german black metal there are 0 extra rows
# DEBUG:root:when adding german dance there are 0 extra rows
# DEBUG:root:when adding german dark minimal techno there are 0 extra rows
# DEBUG:root:when adding german electronica there are 0 extra rows
# DEBUG:root:when adding german hard rock there are 0 extra rows
# DEBUG:root:when adding german heavy metal there are 0 extra rows
# DEBUG:root:when adding german house there are 0 extra rows
# DEBUG:root:when adding german indie there are 0 extra rows
# DEBUG:root:when adding german indie pop there are 0 extra rows
# DEBUG:root:when adding german jazz there are 0 extra rows
# DEBUG:root:when adding german metal there are 0 extra rows
# DEBUG:root:when adding german metalcore there are 0 extra rows
# DEBUG:root:when adding german opera there are 0 extra rows
# DEBUG:root:when adding german pop there are 0 extra rows
# DEBUG:root:when adding german post-hardcore there are 0 extra rows
# DEBUG:root:when adding german power metal there are 0 extra rows
# DEBUG:root:when adding german punk there are 0 extra rows
# DEBUG:root:when adding german punk rock there are 0 extra rows
# DEBUG:root:when adding german rock there are 0 extra rows
# DEBUG:root:when adding german romanticism there are 0 extra rows
# DEBUG:root:when adding german shoegaze there are 0 extra rows
# DEBUG:root:when adding german ska there are 0 extra rows
# DEBUG:root:when adding german soundtrack there are 0 extra rows
# DEBUG:root:when adding german street punk there are 0 extra rows
# DEBUG:root:when adding german tech house there are 0 extra rows
# DEBUG:root:when adding german techno there are 0 extra rows
# DEBUG:root:when adding german thrash metal there are 0 extra rows
# DEBUG:root:when adding german trance there are 0 extra rows
# DEBUG:root:when adding ghanaian hip hop there are 0 extra rows
# DEBUG:root:when adding ghanaian pop there are 0 extra rows
# DEBUG:root:when adding ghent indie there are 0 extra rows
# DEBUG:root:when adding ghettotech there are 0 extra rows
# DEBUG:root:when adding girl group there are 0 extra rows
# DEBUG:root:when adding glam metal there are 0 extra rows
# DEBUG:root:when adding glam rock there are 0 extra rows
# DEBUG:root:when adding glee club there are 0 extra rows
# DEBUG:root:when adding glitch there are 0 extra rows
# DEBUG:root:when adding glitch hop there are 0 extra rows
# DEBUG:root:when adding glitch pop there are 0 extra rows
# DEBUG:root:when adding glitchcore there are 0 extra rows
# DEBUG:root:when adding glitter trance there are 0 extra rows
# DEBUG:root:when adding goa trance there are 0 extra rows
# DEBUG:root:when adding gospel there are 0 extra rows
# DEBUG:root:when adding gospel r&b there are 0 extra rows
# DEBUG:root:when adding gothenburg indie there are 0 extra rows
# DEBUG:root:when adding gothenburg metal there are 0 extra rows
# ...
# DEBUG:root:when adding straight-ahead jazz there are 0 extra rows
# DEBUG:root:when adding street band there are 0 extra rows
# DEBUG:root:when adding street punk there are 0 extra rows
# DEBUG:root:when adding street punk espanol there are 0 extra rows
# DEBUG:root:when adding stride there are 10 extra rows
# DEBUG:root:when adding string band there are 0 extra rows
# DEBUG:root:when adding string quartet there are 0 extra rows
# DEBUG:root:when adding sudanese pop there are 0 extra rows
# DEBUG:root:when adding sufi there are 0 extra rows
# DEBUG:root:when adding sunshine pop there are 0 extra rows
# DEBUG:root:when adding suomisaundi there are 0 extra rows
# DEBUG:root:when adding supergroup there are 0 extra rows
# DEBUG:root:when adding surf punk there are 0 extra rows
# DEBUG:root:when adding svensk progg there are 0 extra rows
# DEBUG:root:when adding swamp rock there are 0 extra rows
# DEBUG:root:when adding swancore there are 0 extra rows
# DEBUG:root:when adding swedish alternative rock there are 0 extra rows
# DEBUG:root:when adding swedish americana there are 0 extra rows
# DEBUG:root:when adding swedish country there are 0 extra rows
# DEBUG:root:when adding swedish death metal there are 0 extra rows
# DEBUG:root:when adding swedish electronic there are 0 extra rows
# DEBUG:root:when adding swedish electropop there are 0 extra rows
# DEBUG:root:when adding swedish garage rock there are 0 extra rows
# DEBUG:root:when adding swedish hard rock there are 0 extra rows
# DEBUG:root:when adding swedish heavy metal there are 0 extra rows
# DEBUG:root:when adding swedish house there are 0 extra rows
# DEBUG:root:when adding swedish indie folk there are 0 extra rows
# DEBUG:root:when adding swedish indie pop there are 0 extra rows
# DEBUG:root:when adding swedish indie rock there are 0 extra rows
# DEBUG:root:when adding swedish melodic rock there are 0 extra rows
# DEBUG:root:when adding swedish metal there are 0 extra rows
# DEBUG:root:when adding swedish pop there are 0 extra rows
# DEBUG:root:when adding swedish power metal there are 0 extra rows
# DEBUG:root:when adding swedish prog there are 0 extra rows
# DEBUG:root:when adding swedish punk there are 0 extra rows
# DEBUG:root:when adding swedish singer-songwriter there are 0 extra rows
# DEBUG:root:when adding swedish synth there are 0 extra rows
# DEBUG:root:when adding swedish synthpop there are 0 extra rows
# DEBUG:root:when adding swing there are 0 extra rows
# DEBUG:root:when adding swiss black metal there are 0 extra rows
# DEBUG:root:when adding swiss metal there are 0 extra rows
# DEBUG:root:when adding swiss pop there are 0 extra rows
# DEBUG:root:when adding swiss punk there are 0 extra rows
# DEBUG:root:when adding swiss rock there are 0 extra rows
# DEBUG:root:when adding swiss techno there are 0 extra rows
# DEBUG:root:when adding symphonic black metal there are 0 extra rows
# DEBUG:root:when adding symphonic death metal there are 0 extra rows
# DEBUG:root:when adding symphonic metal there are 0 extra rows
# DEBUG:root:when adding symphonic power metal there are 0 extra rows
# DEBUG:root:when adding symphonic rock there are 3 extra rows
# DEBUG:root:when adding synth punk there are 0 extra rows
# DEBUG:root:when adding synthesizer there are 0 extra rows
# DEBUG:root:when adding synthpop there are 0 extra rows
# DEBUG:root:when adding synthwave there are 0 extra rows
# DEBUG:root:when adding tagalog worship there are 0 extra rows
# DEBUG:root:when adding taiwan indie there are 0 extra rows
# DEBUG:root:when adding taiwan pop there are 0 extra rows
# DEBUG:root:when adding taiwan singer-songwriter there are 0 extra rows
# DEBUG:root:when adding talent show there are 0 extra rows
# DEBUG:root:when adding tampa indie there are 0 extra rows
# DEBUG:root:when adding tech house there are 1 extra rows
# DEBUG:root:when adding tech trance there are 0 extra rows
# DEBUG:root:when adding technical groove metal there are 0 extra rows
# DEBUG:root:when adding technical thrash there are 0 extra rows
# DEBUG:root:when adding techno argentina there are 0 extra rows
# DEBUG:root:when adding tecnobanda there are 0 extra rows
# DEBUG:root:when adding teen pop there are 0 extra rows
# DEBUG:root:when adding tejano there are 0 extra rows
# DEBUG:root:when adding tekk there are 0 extra rows
# DEBUG:root:when adding tempe indie there are 0 extra rows
# DEBUG:root:when adding tennessee hip hop there are 0 extra rows
# DEBUG:root:when adding tex-mex there are 2 extra rows
# DEBUG:root:when adding texas blues there are 0 extra rows
# DEBUG:root:when adding texas country there are 3 extra rows
# DEBUG:root:when adding texas latin rap there are 0 extra rows
# DEBUG:root:when adding texas pop punk there are 0 extra rows
# DEBUG:root:when adding thai folk there are 0 extra rows
# DEBUG:root:when adding thai folk pop there are 0 extra rows
# DEBUG:root:when adding thai folk rock there are 0 extra rows
# DEBUG:root:when adding thai idol there are 0 extra rows
# DEBUG:root:when adding thai indie there are 0 extra rows
# DEBUG:root:when adding thai instrumental there are 0 extra rows
# DEBUG:root:when adding thai pop there are 1 extra rows
# DEBUG:root:when adding thai rock there are 0 extra rows
# DEBUG:root:when adding thai teen pop there are 0 extra rows
# DEBUG:root:when adding theme there are 0 extra rows
# DEBUG:root:when adding therapy there are 0 extra rows
# DEBUG:root:when adding thrash core there are 0 extra rows
# DEBUG:root:when adding thrash metal there are 0 extra rows
# DEBUG:root:when adding tin pan alley there are 0 extra rows
# DEBUG:root:when adding tolkien metal there are 0 extra rows
# DEBUG:root:when adding torch song there are 0 extra rows
# DEBUG:root:when adding toronto indie there are 0 extra rows
# DEBUG:root:when adding toronto rap there are 0 extra rows
# DEBUG:root:when adding traditional blues there are 0 extra rows
# DEBUG:root:when adding traditional british folk there are 0 extra rows
# DEBUG:root:when adding traditional country there are 0 extra rows
# DEBUG:root:when adding traditional folk there are 0 extra rows
# DEBUG:root:when adding trance there are 13 extra rows
# DEBUG:root:when adding trancecore there are 0 extra rows
# DEBUG:root:when adding trap there are 23 extra rows
# DEBUG:root:when adding trap boricua there are 0 extra rows
# DEBUG:root:when adding trap latino there are 1 extra rows
# DEBUG:root:when adding trap queen there are 0 extra rows
# DEBUG:root:when adding trap soul there are 3 extra rows
# DEBUG:root:when adding traprun there are 0 extra rows
# DEBUG:root:when adding tribal house there are 5 extra rows
# DEBUG:root:when adding trip hop there are 0 extra rows
# DEBUG:root:when adding trival there are 0 extra rows
# DEBUG:root:when adding tropical there are 1 extra rows
# DEBUG:root:when adding tropical house there are 35 extra rows
# DEBUG:root:when adding tropicalia there are 0 extra rows
# DEBUG:root:when adding trot there are 0 extra rows
# DEBUG:root:when adding truck-driving country there are 0 extra rows
# DEBUG:root:when adding tucson indie there are 0 extra rows
# DEBUG:root:when adding tulsa indie there are 0 extra rows
# DEBUG:root:when adding turbo folk there are 0 extra rows
# DEBUG:root:when adding turntablism there are 0 extra rows
# DEBUG:root:when adding twee pop there are 0 extra rows
# DEBUG:root:when adding uk alternative hip hop there are 0 extra rows
# DEBUG:root:when adding uk alternative pop there are 0 extra rows
# DEBUG:root:when adding uk americana there are 0 extra rows
# DEBUG:root:when adding uk contemporary jazz there are 1 extra rows
# DEBUG:root:when adding uk contemporary r&b there are 0 extra rows
# DEBUG:root:when adding uk dance there are 0 extra rows
# DEBUG:root:when adding uk dnb there are 0 extra rows
# DEBUG:root:when adding uk doom metal there are 0 extra rows
# DEBUG:root:when adding uk dub there are 0 extra rows
# DEBUG:root:when adding uk experimental electronic there are 0 extra rows
# DEBUG:root:when adding uk funky there are 0 extra rows
# DEBUG:root:when adding uk garage there are 0 extra rows
# DEBUG:root:when adding uk hip hop there are 0 extra rows
# DEBUG:root:when adding uk house there are 0 extra rows
# DEBUG:root:when adding uk metalcore there are 0 extra rows
# DEBUG:root:when adding uk pop there are 7 extra rows
# DEBUG:root:when adding uk pop punk there are 0 extra rows
# DEBUG:root:when adding uk post-hardcore there are 0 extra rows
# DEBUG:root:when adding uk post-punk there are 0 extra rows
# DEBUG:root:when adding uk reggae there are 0 extra rows
# DEBUG:root:when adding uk worship there are 0 extra rows
# DEBUG:root:when adding ukg revival there are 0 extra rows
# DEBUG:root:when adding ukhc there are 0 extra rows
# DEBUG:root:when adding ukrainian choir there are 0 extra rows
# DEBUG:root:when adding ukrainian classical there are 0 extra rows
# DEBUG:root:when adding ukrainian classical piano there are 0 extra rows
# DEBUG:root:when adding ukrainian electronic there are 0 extra rows
# DEBUG:root:when adding ukrainian folk there are 0 extra rows
# DEBUG:root:when adding ukrainian pop there are 0 extra rows
# DEBUG:root:when adding ukrainian rock there are 0 extra rows
# DEBUG:root:when adding ukulele there are 0 extra rows
# DEBUG:root:when adding unblack metal there are 2 extra rows
# DEBUG:root:when adding underground hip hop there are 4 extra rows
# DEBUG:root:when adding underground power pop there are 0 extra rows
# DEBUG:root:when adding underground rap there are 0 extra rows
# DEBUG:root:when adding uplifting trance there are 14 extra rows
# DEBUG:root:when adding uptempo hardcore there are 0 extra rows
# DEBUG:root:when adding urban contemporary there are 5 extra rows
# DEBUG:root:when adding vallenato there are 0 extra rows
# DEBUG:root:when adding vancouver indie there are 0 extra rows
# DEBUG:root:when adding vancouver metal there are 0 extra rows
# DEBUG:root:when adding vancouver punk there are 0 extra rows
# DEBUG:root:when adding vapor pop there are 0 extra rows
# DEBUG:root:when adding vapor soul there are 5 extra rows
# DEBUG:root:when adding vapor trap there are 7 extra rows
# DEBUG:root:when adding vapor twitch there are 0 extra rows
# DEBUG:root:when adding vaporwave there are 0 extra rows
# DEBUG:root:when adding vegas indie there are 0 extra rows
# DEBUG:root:when adding velha guarda there are 0 extra rows
# DEBUG:root:when adding veracruz indie there are 0 extra rows
# DEBUG:root:when adding victoria bc indie there are 0 extra rows
# DEBUG:root:when adding video game music there are 2 extra rows
# DEBUG:root:when adding vietnamese pop there are 0 extra rows
# DEBUG:root:when adding viking metal there are 0 extra rows
# DEBUG:root:when adding vintage hawaiian there are 0 extra rows
# DEBUG:root:when adding vintage italian soundtrack there are 0 extra rows
# DEBUG:root:when adding vintage schlager there are 1 extra rows
# DEBUG:root:when adding viral pop there are 0 extra rows
# DEBUG:root:when adding viral rap there are 5 extra rows
# DEBUG:root:when adding viral trap there are 0 extra rows
# DEBUG:root:when adding virgin islands reggae there are 0 extra rows
# DEBUG:root:when adding virginia hip hop there are 0 extra rows
# DEBUG:root:when adding virginia metal there are 0 extra rows
# DEBUG:root:when adding visual kei there are 0 extra rows
# DEBUG:root:when adding vocal harmony group there are 0 extra rows
# DEBUG:root:when adding vocal house there are 1 extra rows
# DEBUG:root:when adding vocal jazz there are 1 extra rows
# DEBUG:root:when adding vocal trance there are 0 extra rows
# DEBUG:root:when adding vocaloid there are 0 extra rows
# DEBUG:root:when adding voidgaze there are 1 extra rows
# DEBUG:root:when adding waiata mo tamariki there are 0 extra rows
# DEBUG:root:when adding warm drone there are 0 extra rows
# DEBUG:root:when adding washington indie there are 0 extra rows
# DEBUG:root:when adding wassoulou there are 0 extra rows
# DEBUG:root:when adding water there are 0 extra rows
# DEBUG:root:when adding wave there are 0 extra rows
# DEBUG:root:when adding welsh indie there are 0 extra rows
# DEBUG:root:when adding welsh metal there are 0 extra rows
# DEBUG:root:when adding welsh rock there are 0 extra rows
# DEBUG:root:when adding west african jazz there are 1 extra rows
# DEBUG:root:when adding west coast rap there are 0 extra rows
# DEBUG:root:when adding west coast reggae there are 2 extra rows
# DEBUG:root:when adding west coast trap there are 2 extra rows
# DEBUG:root:when adding west end there are 0 extra rows
# DEBUG:root:when adding west virginia indie there are 0 extra rows
# DEBUG:root:when adding western americana there are 0 extra rows
# DEBUG:root:when adding white noise there are 0 extra rows
# DEBUG:root:when adding women's music there are 0 extra rows
# DEBUG:root:when adding workout product there are 0 extra rows
# DEBUG:root:when adding world there are 1 extra rows
# DEBUG:root:when adding world fusion there are 0 extra rows
# DEBUG:root:when adding world worship there are 1 extra rows
# DEBUG:root:when adding worship there are 0 extra rows
# DEBUG:root:when adding wrestling there are 0 extra rows
# DEBUG:root:when adding wyoming roots there are 0 extra rows
# DEBUG:root:when adding xinyao there are 0 extra rows
# DEBUG:root:when adding xtra raw there are 0 extra rows
# DEBUG:root:when adding yacht rock there are 0 extra rows
# DEBUG:root:when adding yaoi there are 0 extra rows
# DEBUG:root:when adding ye ye there are 0 extra rows
# DEBUG:root:when adding yoga there are 0 extra rows
# DEBUG:root:when adding yugoslav rock there are 0 extra rows
# DEBUG:root:when adding zhongguo feng there are 0 extra rows
# DEBUG:root:when adding zolo there are 0 extra rows
# DEBUG:root:when adding zouk there are 0 extra rows
# DEBUG:root:when adding a cappella there are 2 extra rows
# DEBUG:root:when adding australian indigenous there are 0 extra rows
# DEBUG:root:when adding british orchestra there are 0 extra rows
# DEBUG:root:when adding classical baritone there are 0 extra rows
# DEBUG:root:when adding classical soprano there are 0 extra rows
# DEBUG:root:when adding classical tenor there are 0 extra rows
# DEBUG:root:when adding connecticut indie there are 0 extra rows
# DEBUG:root:when adding deep indian pop there are 1 extra rows
# DEBUG:root:when adding gaming dubstep there are 1 extra rows
# DEBUG:root:when adding german choir there are 0 extra rows
# DEBUG:root:when adding ghazal there are 0 extra rows
# DEBUG:root:when adding italian indie pop there are 2 extra rows
# DEBUG:root:when adding italian tenor there are 0 extra rows
# DEBUG:root:when adding outsider house there are 1 extra rows
# DEBUG:root:when adding russian punk there are 0 extra rows
# DEBUG:root:when adding russian ska there are 0 extra rows
# DEBUG:root:when adding sacred steel there are 0 extra rows
# DEBUG:root:when adding swedish tropical house there are 0 extra rows
# DEBUG:root:when adding synth funk there are 0 extra rows
# DEBUG:root:when adding tamil pop there are 0 extra rows
# DEBUG:root:when adding traditional ska there are 0 extra rows
# DEBUG:root:when adding world chill there are 1 extra rows
# DEBUG:root:when adding acoustic guitar cover there are 0 extra rows
# DEBUG:root:when adding bhojpuri pop there are 1 extra rows
# DEBUG:root:when adding california hardcore there are 1 extra rows
# DEBUG:root:when adding classic greek rock there are 0 extra rows
# DEBUG:root:when adding darkstep there are 0 extra rows
# DEBUG:root:when adding deep space rock there are 0 extra rows
# DEBUG:root:when adding drumfunk there are 0 extra rows
# DEBUG:root:when adding dusseldorf electronic there are 0 extra rows
# DEBUG:root:when adding dutch experimental there are 0 extra rows
# DEBUG:root:when adding dutch experimental electronic there are 0 extra rows
# DEBUG:root:when adding experimental house there are 0 extra rows
# DEBUG:root:when adding greek pop there are 1 extra rows
# DEBUG:root:when adding indie electronica there are 0 extra rows
# DEBUG:root:when adding indie fuzzpop there are 0 extra rows
# DEBUG:root:when adding indonesian r&b there are 0 extra rows
# DEBUG:root:when adding norrbotten indie there are 1 extra rows
# DEBUG:root:when adding russian oi there are 1 extra rows
# DEBUG:root:when adding skansk musik there are 1 extra rows
# DEBUG:root:when adding souldies there are 1 extra rows
# DEBUG:root:when adding surf music there are 2 extra rows
# DEBUG:root:when adding terrorcore there are 0 extra rows

# %% [markdown]
# ### Checkout duplication with the same song being in multiple albums
# - You can have songs in multiple albums. Released the same data (1 album is the generic and another album is the collector's edition)
# - There are songe named 17, 2009 etc. We might want to remove those
# - Let's create a composite name-album index and continue investigating

# %%
dupped = df.groupby(['name', 'album'], as_index = False).agg({'date of data pull':'min'}) 
dedupped = dupped.groupby(['name'], as_index = False).agg({'date of data pull':'count'}).rename({'date of data pull':'row count'},axis = 1 )

list_of_duplicate_names = dedupped[dedupped['row count']>1]['name']

check = df[df['name'].isin(list_of_duplicate_names)]
check.to_excel('investigate.xlsx')

# %% [markdown]
# ### Checkout duplication same song having multiple musical characteristics

# %%
# create a composite index
df["name_album"] = df["name"] + df["album"]

dupped = df.groupby(['name_album', 'length'], as_index = False).agg({'date of data pull':'min'}) 
dedupped = dupped.groupby(['name_album'], as_index = False).agg({'date of data pull':'count'}).rename({'date of data pull':'row count'},axis = 1 )

list_of_duplicate_names = dedupped[dedupped['row count']>1]['name_album']

check = df[df['name_album'].isin(list_of_duplicate_names)]
check.to_excel('investigate.xlsx')

# %% [markdown]
# ## GENERAL
#
# - How many events do we have?
# - are event ID's unique?

# %%
number_of_unique_event_ids = df['event id'].nunique()
number_of_rows = df.shape[0]
number_of_unique_events = df['event name'].nunique()

if number_of_unique_event_ids == number_of_rows:
    print('The data set has one row per event id')
else:
    print('The data set has', number_of_rows, 'rows but only',  number_of_unique_event_ids, 'unique event ids')

pd.set_option('display.max_rows',120)
# Out:
# The data set has 140 rows but only 139 unique event ids

# %% [markdown]
# ## DUPLICATION
#
# - Events with the same ID keep on reappearing with different information
# - What changes?

# %%
# Create a dedupped data set with a row count of the duplicate rows
check_duplicates = df[['event id','info']].groupby(['event id'], as_index = False).count().rename({'info':'duplication count'}, axis = 1)

# Put the duplicate event ids in a list
list_of_duplicate_event_ids = list(check_duplicates[check_duplicates['duplication count']>1]['event id'])

# Add the duplication counter and export the duplicate rows for review
duplicate_rows = df[df['event id'].isin(list_of_duplicate_event_ids)]

duplicate_rows_with_dup_counter = pd.merge(
    duplicate_rows, check_duplicates
    ,how = 'inner'
    ,left_on = 'event id'
    ,right_on = 'event id'
    )   

# duplicate_rows_with_dup_counter.to_excel('~/downloads/check ticketmaster duplication.xlsx')

# %% [markdown]
# ## EDA of Caregorical Variables
#
# - Are certain venues more prolific?
# - Breakout of event types. Tabs and Crosstabs
# - How is ticket limit looking?

# %%
freq = df.groupby('venue name').agg({'info':'count'}).rename({'info':'row count'}, axis = 1)
freq['%'] = freq['row count']/df.shape[0]
freq


for type_var in ['segment', 'genre', 'subGenre', 'type', 'subType', 'ticket limit']:

    freq = df.groupby(type_var).agg({'info':'count'}).rename({'info':'row count'}, axis = 1)
    freq['%'] = freq['row count']/df.shape[0]
    freq
    

freq = pd.crosstab(df['segment'], df['genre'])
freq

freq = pd.crosstab(df['segment'], df['subGenre'])
freq

freq = pd.crosstab(df['genre'], df['subGenre'])
freq
# Out:
#                                                  row count         %
# venue name
# Carolina Theatre                                         4  0.029851
# Coastal Credit Union Music Park at Walnut Creek          0  0.000000
# DPAC - Durham Performing Arts Center                    60  0.447761
# Duke Energy Center for the Performing Arts               0  0.000000
# Florence Center                                          0  0.000000
# PNC Arena                                                2  0.014925
# Raleigh Improv                                           0  0.000000
# Red Hat Amphitheater                                     0  0.000000
# Steven Tanger Center for the Performing Arts            20  0.149254
#                 row count         %
# segment
# Arts & Theatre         67  0.500000
# Miscellaneous          13  0.097015
# Music                   4  0.029851
# Sports                  2  0.014925
# Undefined               0  0.000000
#            row count         %
# genre
# Classical          5  0.037313
# Comedy             2  0.014925
# Country            1  0.007463
# Hockey             2  0.014925
# Jazz               0  0.000000
# Opera              0  0.000000
# Other              0  0.000000
# R&B                1  0.007463
# Rock               2  0.014925
# Theatre           60  0.447761
# Undefined         13  0.097015
#            row count         %
# subGenre
# Bluegrass          1  0.007463
# Comedy             2  0.014925
# Jazz               0  0.000000
# Musical           60  0.447761
# NHL                2  0.014925
# Opera              0  0.000000
# Other              0  0.000000
# Pop                2  0.014925
# R&B                1  0.007463
# Symphonic          5  0.037313
# Undefined         13  0.097015
#              row count         %
# type
# Event Style          0  0.000000
# Group                2  0.014925
# Merchandise          0  0.000000
# Undefined           71  0.529851
# Upsell              13  0.097015
#                   row count         %
# subType
# Competition               0  0.000000
# Gift Certificate          0  0.000000
# Special Entry            13  0.097015
# Team                      2  0.014925
# Undefined                71  0.529851
#                                                     row count         %
# ticket limit
# OFF                                                         0  0.000000
# There is an overall 6 ticket limit for this event.          1  0.007463
# There is an overall 8 ticket limit for this event.         63  0.470149
# genre           Classical  Comedy  Country  Hockey  Jazz  Opera  Other  R&B  \
# segment
# Arts & Theatre          7      31        0       0     0      1      0    0
# Miscellaneous           0       0        0       0     0      0      0    0
# Music                   0       0        1       0     1      0      2    1
# Sports                  0       0        0       2     0      0      0    0
# Undefined               0       0        0       0     0      0      0    0
#
# genre           Rock  Theatre  Undefined
# segment
# Arts & Theatre     0       68          0
# Miscellaneous      0        0         15
# Music              4        0          0
# Sports             0        0          0
# Undefined          0        0          1
# subGenre        Bluegrass  Comedy  Jazz  Musical  NHL  Opera  Other  Pop  R&B  \
# segment
# Arts & Theatre          0      31     0       68    0      1      0    0    0
# Miscellaneous           0       0     0        0    0      0      0    0    0
# Music                   1       0     1        0    0      0      2    4    1
# Sports                  0       0     0        0    2      0      0    0    0
# Undefined               0       0     0        0    0      0      0    0    0
#
# subGenre        Symphonic  Undefined
# segment
# Arts & Theatre          7          0
# Miscellaneous           0         15
# Music                   0          0
# Sports                  0          0
# Undefined               0          1
# subGenre   Bluegrass  Comedy  Jazz  Musical  NHL  Opera  Other  Pop  R&B  \
# genre
# Classical          0       0     0        0    0      0      0    0    0
# Comedy             0      31     0        0    0      0      0    0    0
# Country            1       0     0        0    0      0      0    0    0
# Hockey             0       0     0        0    2      0      0    0    0
# Jazz               0       0     1        0    0      0      0    0    0
# Opera              0       0     0        0    0      1      0    0    0
# Other              0       0     0        0    0      0      2    0    0
# R&B                0       0     0        0    0      0      0    0    1
# Rock               0       0     0        0    0      0      0    4    0
# Theatre            0       0     0       68    0      0      0    0    0
# Undefined          0       0     0        0    0      0      0    0    0
#
# subGenre   Symphonic  Undefined
# genre
# Classical          7          0
# Comedy             0          0
# Country            0          0
# Hockey             0          0
# Jazz               0          0
# Opera              0          0
# Other              0          0
# R&B                0          0
# Rock               0          0
# Theatre            0          0
# Undefined          0         16

# %% [markdown]
# ## EDA of Caregorical Variables
#
# - What is the range of the date variables?
# - Are there missing event start dates?
# - price ranges (outliers, etc)

# %%
date_vars = ['public sales startDateTime', 'public sales endDateTime', 'event start dateTime', 'event initial start dateTime']

for date_var in date_vars: 
    df[date_var] = pd.to_datetime(df[date_var])

print("N should be", df.shape[0]) 
    
df[date_vars].describe(datetime_is_numeric=True)

df[['price min', 'price max']].describe()
# Out:
# N should be 134
#                 public sales startDateTime  \
# count                                   74
# mean   2020-01-06 08:55:08.108108032+00:00
# min              2009-09-12 00:00:00+00:00
# 25%              2020-01-13 15:00:00+00:00
# 50%              2020-02-17 17:00:00+00:00
# 75%              2020-09-12 14:00:00+00:00
# max              2021-03-05 15:00:00+00:00
#
#                   public sales endDateTime  \
# count                                   74
# mean   2021-09-06 08:09:18.648648704+00:00
# min              2021-03-18 22:00:00+00:00
# 25%              2021-05-21 23:52:30+00:00
# 50%              2021-08-18 00:15:00+00:00
# 75%              2021-12-31 03:52:30+00:00
# max              2022-06-19 23:00:00+00:00
#
#                       event start dateTime  \
# count                                  131
# mean   2021-11-16 15:06:24.274809088+00:00
# min              2021-03-18 22:00:00+00:00
# 25%              2021-07-24 23:45:00+00:00
# 50%              2021-12-09 00:30:00+00:00
# 75%              2022-03-14 23:45:00+00:00
# max              2022-08-07 23:00:00+00:00
#
#               event initial start dateTime
# count                                   63
# mean   2021-02-26 17:22:51.428571648+00:00
# min              2020-03-17 00:00:00+00:00
# 25%              2021-01-17 01:00:00+00:00
# 50%              2021-03-17 23:30:00+00:00
# 75%              2021-04-24 09:00:00+00:00
# max              2021-09-26 23:00:00+00:00
#        price min   price max
# count  99.000000   99.000000
# mean   33.029495  111.926465
# std     9.387486   46.950733
# min    15.000000   15.000000
# 25%    30.000000   82.500000
# 50%    35.000000  129.500000
# 75%    35.000000  139.500000
# max    75.000000  295.000000

# %% [markdown]
# ## Are prices moving? (TBD)
